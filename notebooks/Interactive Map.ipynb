# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np

# %matplotlib inline

# %% [markdown]
# We will continue from the EDA in the last notebook and try to produce a visualisation that captures the natural disaster incidents information. First we need to do some preprocessing to get our data in the format we want.

# %%
data_dir = '../data'

processed_oilspills_csvpath = os.path.join(data_dir, 'US_oilspills_p1.csv')
US_shapely_filepath = os.path.join(data_dir, 'states_21basic/states.shp')

# %%
oilspills = pd.read_csv(processed_oilspills_csvpath, index_col='id', parse_dates=['open_date'])

oilspills.head(3)
# Out:
#        open_date                                               name  \
# id
# 10049 2020-02-27  Partially Submerged Recreational Vessel Huron ...
# 10050 2020-02-27         Whitney Tank Battery 160 Loomis Pass Spill
# 10048 2020-02-24                                 Gray whale carcass
#
#                location        lat         lon threat commodity  \
# id
# 10049         Huron, OH  41.391532  -82.554591    Oil       NaN
# 10050   Venice, LA, USA  29.116625  -89.180917    Oil       NaN
# 10048  Port Hueneme, CA  34.149744 -119.208226  Other       NaN
#
#        max_ptl_release_gallons  \
# id
# 10049                      NaN
# 10050                      NaN
# 10048                      NaN
#
#                                              description  year  month  \
# id
# 10049  On February 27, 2020, SSC received notificatio...  2020      2
# 10050  On February 27, 2020, the USCG Sector New Orle...  2020      2
# 10048  On 24-FEB-2020, NMFS Stranding Coordinator in ...  2020      2
#
#       commodity_key_tokens                             description_key_tokens
# id
# 10049                  NaN  [('February 27, 2020', 'DATE'), ('34', 'CARDIN...
# 10050                  NaN  [('February 27, 2020', 'DATE'), ('the USCG Sec...
# 10048                  NaN  [('24-FEB-2020', 'CARDINAL'), ('NMFS Stranding...

# %%
oilspills.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3709 entries, 10049 to 6200
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   open_date                3709 non-null   datetime64[ns]
#  1   name                     3709 non-null   object
#  2   location                 3707 non-null   object
#  3   lat                      3709 non-null   float64
#  4   lon                      3709 non-null   float64
#  5   threat                   2413 non-null   object
#  6   commodity                3101 non-null   object
#  7   max_ptl_release_gallons  2074 non-null   float64
#  8   description              1776 non-null   object
#  9   year                     3709 non-null   int64
#  10  month                    3709 non-null   int64
#  11  commodity_key_tokens     3101 non-null   object
#  12  description_key_tokens   1776 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(2), object(7)
# memory usage: 405.7+ KB

# %%
# US_gpd = gpd.read_file(US_shapely_filepath)
# US_gpd.head()

# fig, ax = plt.subplots(figsize = (10,10))
# US_gpd.plot(ax=ax)

# %% [markdown]
# First, we have to fill in our NaN values

# %%
nan_value_mapping = {
    'location': 'unknown',
    'threat': 'unknown',
    'commodity': '',
    'description': '',
    'max_ptl_release_gallons': -1
}

# %%
oilspills = oilspills.fillna(value=nan_value_mapping)

# %%
oilspills.head()
# Out:
#        open_date                                               name  \
# id
# 10049 2020-02-27  Partially Submerged Recreational Vessel Huron ...
# 10050 2020-02-27         Whitney Tank Battery 160 Loomis Pass Spill
# 10048 2020-02-24                                 Gray whale carcass
# 10047 2020-02-20  Recreational vessel sunk in Anacortes Skyline ...
# 10046 2020-02-17                  North Santiam River - Truck Spill
#
#                                          location        lat         lon  \
# id
# 10049                                   Huron, OH  41.391532  -82.554591
# 10050                             Venice, LA, USA  29.116625  -89.180917
# 10048                            Port Hueneme, CA  34.149744 -119.208226
# 10047  2400 Skyline Way, Anacortes, WA 98221, USA  48.492559 -122.680368
# 10046       N Santiam Hwy, Detroit, OR 97342, USA  44.697000 -122.226890
#
#       threat commodity  max_ptl_release_gallons  \
# id
# 10049    Oil                               -1.0
# 10050    Oil                               -1.0
# 10048  Other                               -1.0
# 10047    Oil                               -1.0
# 10046    Oil                               -1.0
#
#                                              description  year  month  \
# id
# 10049  On February 27, 2020, SSC received notificatio...  2020      2
# 10050  On February 27, 2020, the USCG Sector New Orle...  2020      2
# 10048  On 24-FEB-2020, NMFS Stranding Coordinator in ...  2020      2
# 10047  On February 20, 2020, the SEA WOLF, a 44 foot ...  2020      2
# 10046  On the morning of 16 FEB 2020 along the  Santi...  2020      2
#
#       commodity_key_tokens                             description_key_tokens
# id
# 10049                  NaN  [('February 27, 2020', 'DATE'), ('34', 'CARDIN...
# 10050                  NaN  [('February 27, 2020', 'DATE'), ('the USCG Sec...
# 10048                  NaN  [('24-FEB-2020', 'CARDINAL'), ('NMFS Stranding...
# 10047                  NaN  [('February 20, 2020', 'DATE'), ('44 foot', 'Q...
# 10046                  NaN  [('the morning', 'TIME'), ('Santiam River', 'L...

# %%
# fig = px.scatter_geo(oilspills, 
#                      lat='lat',
#                      lon='lon',
#                      color="threat",
#                      hover_name="name", 
#                      animation_frame="year",
#                      projection="natural earth")
# fig.show()
# Out:
# <div>
#
#
#             <div id="ba81836c-3170-4b49-be99-a71b5bb0e084" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ba81836c-3170-4b49-be99-a71b5bb0e084")) {
#                     Plotly.newPlot(
#                         'ba81836c-3170-4b49-be99-a71b5bb0e084',
#                         [{"geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>threat=Oil<br>year=2020<br>lat=%{lat}<br>lon=%{lon}<extra></extra>", "hovertext": ["Partially Submerged Recreational Vessel Huron Harbor Marina", "Whitney Tank Battery 160 Loomis Pass Spill", "Recreational vessel sunk in Anacortes Skyline Marina", "North Santiam River - Truck Spill", "Mystery Red Dyed Diesel Spill Venice Marina", "Diesel Spill - Unknown Source", "Fishing Vessel Aground on Shackleford Banks, NC", "Gaubert Oil Diesel Spill", "Small plane crash", "GARROW BEND Sunken Tug", "Grounded Vessel, Hilo, Hawaii", "Mystery Oil Slick Viosca Knoll Block 989", "Tabbs Bay Discharge, Baytown, TX", "Mystery Sheen Mississippi River mm93", "50 gal diesel spill Old Fort Bayou NRC 1269451", "Possible sheen report", "LifeMed Airplane Crash", "FV Pappy's Pride", "FV Scandies Rose sinking"], "lat": [41.391532, 29.116625, 48.49255855, 44.697, 29.2401303, 47.54195085, 34.65218888, 29.598269, 40.824202, 30.655199, 19.74280556, 28.935, 29.7090345, 29.95, 30.419132, 38.7, 53.90944, 29.33719257, 56.49172], "legendgroup": "Oil", "lon": [-82.554591, -89.18091667, -122.6803676, -122.22689, -89.3645153, -122.6411712, -76.62304698, -90.663037, -124.1421604, -88.0429989, -155.08875, -88.635, -94.9843738, -90.01972222, -88.827474, -123.433, -166.55638000000005, -94.68285995, -157.0178], "marker": {"color": "#636efa"}, "name": "Oil", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>threat=Other<br>year=2020<br>lat=%{lat}<br>lon=%{lon}<extra></extra>", "hovertext": ["Gray whale carcass", "Lost dredge Hose", "Buoy Adrift and Lost: Long Island Sound"], "lat": [34.14974372, 29.61666667, 41.22944444], "legendgroup": "Other", "lon": [-119.2082262, -80.71666667, -72.06638889], "marker": {"color": "#EF553B"}, "name": "Other", "showlegend": true, "type": "scattergeo"}, {"geo": "geo", "hovertemplate": "<b>%{hovertext}</b><br><br>threat=Chemical<br>year=2020<br>lat=%{lat}<br>lon=%{lon}<extra></extra>", "hovertext": ["Diesel and sulfuric acid discharge in Mississippi River MM 123"], "lat": [29.95365], "legendgroup": "Chemical", "lon": [-90.393498], "marker": {"color": "#00cc96"}, "name": "Chemical", "showlegend": true, "type": "scattergeo"}],
#                         {"geo": {"center": {}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "projection": {"type": "natural earth"}}, "legend": {"title": {"text": "threat"}, "tracegroupgap": 0}, "margin": {"t": 60}, "sliders": [{"active": 0, "currentvalue": {"prefix": "year="}, "len": 0.9, "pad": {"b": 10, "t": 60}, "steps": [{"args": [["2020"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2020", "method": "animate"}, {"args": [["2019"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2019", "method": "animate"}, {"args": [["2018"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2018", "method": "animate"}, {"args": [["2017"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2017", "method": "animate"}, {"args": [["2016"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2016", "method": "animate"}, {"args": [["2015"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2015", "method": "animate"}, {"args": [["2014"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2014", "method": "animate"}, {"args": [["2013"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2013", "method": "animate"}, {"args": [["2012"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2012", "method": "animate"}, {"args": [["2011"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2011", "method": "animate"}, {"args": [["2010"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2010", "method": "animate"}, {"args": [["2009"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2009", "method": "animate"}, {"args": [["2008"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2008", "method": "animate"}, {"args": [["2007"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2007", "method": "animate"}, {"args": [["2006"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2006", "method": "animate"}, {"args": [["2005"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2005", "method": "animate"}, {"args": [["2004"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2004", "method": "animate"}, {"args": [["2003"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"duration": 0, "easing": "linear"}}], "label": "2003", "method": "animate"}, {"args": [["2002"], {"frame": {"duration": 0, "redraw": true}, "fromcurrent": true, "mode": "immediate", "transition": {"dura ...
